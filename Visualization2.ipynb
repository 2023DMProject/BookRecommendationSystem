# %%
pip show pandas
# Out:
# Name: pandas
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: altair, arviz, bigframes, bokeh, bqplot, cmdstanpy, cufflinks, datascience, db-dtypes, dopamine-rl, fastai, geemap, geopandas, google-colab, gspread-dataframe, holoviews, ibis-framework, lida, mizani, mlxtend, pandas-datareader, pandas-gbq, panel, plotnine, prophet, pymc, seaborn, sklearn-pandas, statsmodels, vega-datasets, xarray, yfinance

# %%
pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 파일 로드
# 예시 데이터 파일 형식: users.csv (유저 데이터), books.csv (책 데이터), ratings.csv (평점 데이터)
users = pd.read_csv('Users.csv')
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Filtered_Ratings.csv')

# 1. 평균 유저 나이 계산
average_user_age = users['Age'].mean()
print(f'평균 유저 나이: {average_user_age:.2f} 세')

# 2. 평균적으로 읽은 책의 수 계산
average_books_per_user = ratings.groupby('User-ID')['ISBN'].size().mean()
print(f'평균적으로 읽은 책의 수: {average_books_per_user:.2f} 권')

# 3. 책의 평균 평점 (0점 제외) 계산
average_book_rating = ratings[ratings['Book-Rating'] > 0]['Book-Rating'].mean()
print(f'책의 평균 평점 (0점 제외): {average_book_rating:.2f}')

# 1. 평균 유저 나이 시각화
user_age_counts = users['Age'].value_counts().sort_index()
plt.bar(user_age_counts.index, user_age_counts.values)
plt.xlabel('age')
plt.ylabel('count')
plt.title('User Age Distribution')
plt.xlim(15, 100)
plt.show()

# 2. 평균적으로 읽은 책의 수 시각화
books_per_user = ratings.groupby('User-ID')['ISBN'].size()
books_per_user_counts = books_per_user.value_counts().sort_index()
plt.hist(books_per_user, bins=30, edgecolor='black')
plt.xlabel('Book Count')
plt.ylabel('User Number')
plt.title('Read Book Distribution')
plt.xlim(0, 1250)
plt.show()


# 3. 책의 평균 평점(0점 제외) 시각화
average_ratings = ratings[ratings['Book-Rating'] > 0].groupby('ISBN')['Book-Rating'].size()
average_ratings_counts = average_ratings.value_counts().sort_index()
plt.bar(average_ratings_counts.index, average_ratings_counts.values)
plt.xlabel('Rating')
plt.ylabel('Book Count')
plt.title('Book Rate Distriburion')
plt.xlim(0, 10)
plt.show()
# Out:
# <ipython-input-6-b8d9645e0946>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')
# 평균 유저 나이: 34.75 세
# 평균적으로 읽은 책의 수: 11.20 권
# 책의 평균 평점 (0점 제외): 7.63
